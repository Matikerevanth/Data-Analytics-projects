# %%
# Loading libraries
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# loading the dataset
bank_df = pd.read_csv(r"C:\Users\jrbil\OneDrive\Desktop\Data science\UDEMY\Data Analytics projects\Bank Domain\bank.csv",sep=';')

# %%
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# datatype of the dataset
type(bank_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# lenggth of the dataset
len(bank_df)
# Out:
# 4521

# %%
# shape of the datset
bank_df.shape
# Out:
# (4521, 17)

# %%
# size pf the dataset
bank_df.size
# Out:
# 76857

# %%
# columns
bank_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
len(bank_df.columns)
# Out:
# 17

# %%
type(bank_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# top 5 rows 
bank_df.head(5)
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
# last 5 rows 
bank_df.tail(5)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
bank_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
dtypes = bank_df.dtypes
dtypes.values
# Out:
# array([dtype('int64'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'),
#        dtype('O'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('O'), dtype('O')], dtype=object)

# %%
dtypes = bank_df.dtypes
dtypes.keys()
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
for i,j in dtypes.items():
    if j=='object':
        print(i)
# Out:
# job
# marital
# education
# default
# housing
# loan
# contact
# month
# poutcome
# y

# %%
# numeric columns
numerical_cols = bank_df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical Columns:")
print(numerical_cols)
# Out:
# Numerical Columns:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
categorical_cols = bank_df.select_dtypes(include=['object', 'category']).columns
print("Categorical Columns:")
print(categorical_cols)
# Out:
# Categorical Columns:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
bank_df.select_dtypes(include='object')
# Out:
#                 job  marital  education default housing loan   contact month  \
# 0        unemployed  married    primary      no      no   no  cellular   oct
# 1          services  married  secondary      no     yes  yes  cellular   may
# 2        management   single   tertiary      no     yes   no  cellular   apr
# 3        management  married   tertiary      no     yes  yes   unknown   jun
# 4       blue-collar  married  secondary      no     yes   no   unknown   may
# ...             ...      ...        ...     ...     ...  ...       ...   ...
# 4516       services  married  secondary      no     yes   no  cellular   jul
# 4517  self-employed  married   tertiary     yes     yes  yes   unknown   may
# 4518     technician  married  secondary      no      no   no  cellular   aug
# 4519    blue-collar  married  secondary      no      no   no  cellular   feb
# 4520   entrepreneur   single   tertiary      no     yes  yes  cellular   apr
#
#      poutcome   y
# 0     unknown  no
# ...

# %%
bank_df.select_dtypes(exclude='object')
# Out:
#       age  balance  day  duration  campaign  pdays  previous
# 0      30     1787   19        79         1     -1         0
# 1      33     4789   11       220         1    339         4
# 2      35     1350   16       185         1    330         1
# 3      30     1476    3       199         4     -1         0
# 4      59        0    5       226         1     -1         0
# ...   ...      ...  ...       ...       ...    ...       ...
# 4516   33     -333   30       329         5     -1         0
# 4517   57    -3313    9       153         1     -1         0
# 4518   57      295   19       151        11     -1         0
# 4519   28     1137    6       129         4    211         3
# 4520   44     1136    3       345         2    249         7
#
# [4521 rows x 7 columns]

# %%
# find missing values 
bank_df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
dtypes = bank_df.dtypes
pd.DataFrame(dtypes.items(), columns=['column name', 'data type'])
# Out:
#    column name data type
# 0          age     int64
# 1          job    object
# 2      marital    object
# 3    education    object
# 4      default    object
# 5      balance     int64
# 6      housing    object
# 7         loan    object
# 8      contact    object
# 9          day     int64
# 10       month    object
# 11    duration     int64
# 12    campaign     int64
# 13       pdays     int64
# 14    previous     int64
# 15    poutcome    object
# 16           y    object

# %%
dict(bank_df.dtypes)
# Out:
# {'age': dtype('int64'),
#  'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'balance': dtype('int64'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'day': dtype('int64'),
#  'month': dtype('O'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
df=dict(bank_df.dtypes)
pd.DataFrame(df,index=['D'])
# Out:
#      age     job marital education default balance housing    loan contact  \
# D  int64  object  object    object  object   int64  object  object  object
#
#      day   month duration campaign  pdays previous poutcome       y
# D  int64  object    int64    int64  int64    int64   object  object

# %%
rows = [1,10,100]
bank_df.take(rows,axis=0)
# Out:
#      age          job  marital  education default  balance housing loan  \
# 1     33     services  married  secondary      no     4789     yes  yes
# 10    39     services  married  secondary      no     9374     yes   no
# 100   36  blue-collar  married  secondary      no        0     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# 1    cellular   11   may       220         1    339         4  failure  no
# 10    unknown   20   may       273         1     -1         0  unknown  no
# 100   unknown    6   may       337         1     -1         0  unknown  no

# %%
columns=[1,10]
bank_df.take(columns, axis=1)
# Out:
#                 job month
# 0        unemployed   oct
# 1          services   may
# 2        management   apr
# 3        management   jun
# 4       blue-collar   may
# ...             ...   ...
# 4516       services   jul
# 4517  self-employed   may
# 4518     technician   aug
# 4519    blue-collar   feb
# 4520   entrepreneur   apr
#
# [4521 rows x 2 columns]

# %%
rows = [120,150]
columns=[3,15]
bank_df.iloc[rows,columns]
# Out:
#      education poutcome
# 120  secondary  unknown
# 150    unknown  unknown

# %%
type(bank_df)
# Out:
# pandas.core.frame.DataFrame

# %%
bank_df['education']
# Out:
# 0         primary
# 1       secondary
# 2        tertiary
# 3        tertiary
# 4       secondary
#           ...
# 4516    secondary
# 4517     tertiary
# 4518    secondary
# 4519    secondary
# 4520     tertiary
# Name: education, Length: 4521, dtype: object

# %%
bank_df[['education']]
# Out:
#       education
# 0       primary
# 1     secondary
# 2      tertiary
# 3      tertiary
# 4     secondary
# ...         ...
# 4516  secondary
# 4517   tertiary
# 4518  secondary
# 4519  secondary
# 4520   tertiary
#
# [4521 rows x 1 columns]

# %%
bank_df[['education','housing', 'age']]
# Out:
#       education housing  age
# 0       primary      no   30
# 1     secondary     yes   33
# 2      tertiary     yes   35
# 3      tertiary     yes   30
# 4     secondary     yes   59
# ...         ...     ...  ...
# 4516  secondary     yes   33
# 4517   tertiary     yes   57
# 4518  secondary      no   57
# 4519  secondary      no   28
# 4520   tertiary     yes   44
#
# [4521 rows x 3 columns]

# %%
education_vc = bank_df['education'].value_counts()
education_vc
# Out:
# education
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: count, dtype: int64

# %%
# Univarient
education_vc = bank_df['education'].value_counts()
keys=education_vc.keys()
values=education_vc.values
plt.bar(keys,values)
# Out:
# <BarContainer object of 4 artists>

# %%
education_vc=bank_df['education'].value_counts().keys()
education_vc=bank_df['education'].value_counts().values
plt.figure(figsize=(10,6))# 10 units x-axis , 6 units y-axis
plt.bar(keys,values)
plt.xlabel('Labels')
plt.ylabel('count')
plt.title('Continent_Bar_Chart')
plt.show()

# %%
for col in categorical_cols:
    plt.figure(figsize=(10,6))
    value_counts = bank_df[col].value_counts()
    plt.bar(value_counts.index, value_counts.values)
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.title(f'{col} - Bar Chart')
    plt.xticks(rotation=45)
    plt.show()

# %%
for i in categorical_cols:
    print(i)
# Out:
# job
# marital
# education
# default
# housing
# loan
# contact
# month
# poutcome
# y

# %%
categorical_cols=bank_df.select_dtypes(include='object').columns
numerical_cols=bank_df.select_dtypes(exclude='object').columns
n=len(categorical_cols)-1
plt.figure(figsize=(28,14))
for i in range(n):
    labels=bank_df[categorical_cols[i+1]].value_counts().keys()
    values=bank_df[categorical_cols[i+1]].value_counts().values
    plt.subplot(3,3,i+1)
    plt.bar(labels,values)
    plt.xlabel('labels')
    plt.ylabel('count')
    plt.title(f'{categorical_cols[i]}_Bar_chart')
    plt.show()

# %%
import math

n = len(categorical_cols)
cols = 3                  # number of columns in subplot grid
rows = math.ceil(n / cols)  # automatically calculate rows

plt.figure(figsize=(5*cols, 5*rows))

for i in range(n):
    plt.subplot(rows, cols, i+1)
    value_counts = bank_df[categorical_cols[i]].value_counts()
    plt.pie(value_counts.values, labels=value_counts.index, autopct='%0.2f%%')
    plt.title(categorical_cols[i])

plt.tight_layout()
plt.show()

# %%
bank_df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
age_data=bank_df['age']
age_data.mean()==age_data.median()
# Out:
# False

# %%
plt.boxplot(age_data,vert=False)
plt.show()

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
plt.hist(age_data,bins=40)
plt.title('histogram')
plt.subplot(1,2,2)
plt.boxplot(age_data,vert=False)
plt.title('boxplot')
plt.subtitle('age_data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 8
#       6 plt.boxplot(age_data,vert=False)
#       7 plt.title('boxplot')
# ----> 8 plt.subtitle('age_data')
#       9 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subtitle'
